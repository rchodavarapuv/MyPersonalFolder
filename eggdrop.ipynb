# %% [markdown]
# <a href="https://colab.research.google.com/github/rchodavarapuv/MyPersonalFolder/blob/master/eggdrop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
def eggDrop(n, k):
 
    # If there are no floors, then no trials
    # needed. OR if there is one floor, one
    # trial needed.
    if (k == 1 or k == 0):
        return k
 
    # We need k trials for one egg
    # and k floors
    if (n == 1):
        return k
 
    min = sys.maxsize
 
    # Consider all droppings from 1st
    # floor to kth floor and return
    # the minimum of these values plus 1.
    for x in range(1, k + 1):
 
        res = max(eggDrop(n - 1, x - 1),
                  eggDrop(n, k - x))
        if (res < min):
            min = res
 
    return min + 1
 
# Driver Code
if __name__ == "__main__":
 
    n = 2
    k = 100
    print("Minimum number of trials in worst case with",
           n, "eggs and", k, "floors is", eggDrop(n, k))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-59866a3db761> in <module>()
#      34     k = 100
#      35     print("Minimum number of trials in worst case with",
# ---> 36            n, "eggs and", k, "floors is", eggDrop(n, k))
#      37
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      22
#      23         res = max(eggDrop(n - 1, x - 1),
# ---> 24                   eggDrop(n, k - x))
#      25         if (res < min):
#      26             min = res
#
# <ipython-input-3-59866a3db761> in eggDrop(n, k)
#      24                   eggDrop(n, k - x))
#      25         if (res < min):
# ---> 26             min = res
#      27
#      28     return min + 1
#
# KeyboardInterrupt:
